# %%
print('lets scrape some tunes')
# Out:
# lets scrape some tunes

# %%
from data_pipeline.setscraper import scrape_bbc6_episode, analyze_multiple_djs

# %%
episode_urls = [
    "https://www.bbc.co.uk/programmes/m002845d",  # Lauren Laverne
    "https://www.bbc.co.uk/programmes/m002f901",  # Tom Ravenscroft (replace with actual URL)
    # Add URLs for other DJs
]

# %%
analyze_multiple_djs(episode_urls)
# Out:
# Successfully loaded: https://www.bbc.co.uk/programmes/m002845d
# DJ: Lauren Laverne
# Episode: A deep dive into suitably great music
# Clicked 'Show more' button
# Found 39 music segments
# Successfully loaded: https://www.bbc.co.uk/programmes/m002f901
# DJ: Lauren Laverne
# Episode: Jump start your mid-morning with the biggest and brightest tunes
# Clicked 'Show more' button
# Found 42 music segments
#                 dj                                            episode  \
# 0   Lauren Laverne              A deep dive into suitably great music
# 1   Lauren Laverne              A deep dive into suitably great music
# 2   Lauren Laverne              A deep dive into suitably great music
# 3   Lauren Laverne              A deep dive into suitably great music
# 4   Lauren Laverne              A deep dive into suitably great music
# ..             ...                                                ...
# 76  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 77  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 78  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 79  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 80  Lauren Laverne  Jump start your mid-morning with the biggest a...
#
#             artist                                     title featured_artists
# 0       Wolf Alice                   Don't Delete The Kisses             None
# 1   Fontaines D.C.                  It's Amazing To Be Young             None
# 2           Prince                               Controversy             None
# 3       Lou Hayter  Frequency (Joe Goddard & Al Doyle Remix)             None
# 4            Yello                                   Bostich             None
# ..             ...                                       ...              ...
# 76     Nina Simone                            See Line Woman             None
# 77    Been Stellar                                 Breakaway             None
# 78         Wet Leg                                  Angelica             None
# 79         J Dilla                                    U-Love             None
# 80          Wookie                                Down On Me             None
#
# [81 rows x 5 columns]

# %%
tracks = scrape_bbc6_episode("https://www.bbc.co.uk/programmes/m002845d")
print(tracks)
# Out:
# Successfully loaded: https://www.bbc.co.uk/programmes/m002845d
# DJ: Lauren Laverne
# Episode: A deep dive into suitably great music
# Clicked 'Show more' button
# Found 39 music segments
# [{'artist': 'Wolf Alice', 'title': "Don't Delete The Kisses"}, {'artist': 'Fontaines D.C.', 'title': "It's Amazing To Be Young"}, {'artist': 'Prince', 'title': 'Controversy'}, {'artist': 'Lou Hayter', 'title': 'Frequency (Joe Goddard & Al Doyle Remix)'}, {'artist': 'Yello', 'title': 'Bostich'}, {'artist': 'Snapped Ankles', 'title': 'Raoul'}, {'artist': 'Jacob Alon', 'title': 'Liquid Gold 25'}, {'artist': 'Sly & the Family Stone', 'title': 'Stand!'}, {'artist': 'Iggy Pop', 'title': 'Family Affair'}, {'artist': 'Sly & the Family Stone', 'title': 'Sing A Simple Song'}, {'artist': 'Jungle Brothers', 'title': 'Because I Got It Like That'}, {'artist': 'Janet Jackson', 'title': 'Rhythm Nation'}, {'artist': 'St Germain', 'title': 'Rose Rouge'}, {'artist': 'Emma‐Jean Thackray', 'title': 'Wanna Die'}, {'artist': 'Obongjayar', 'title': 'Not In Surrender'}, {'artist': 'Femi Kuti', 'title': 'After 24 Years'}, {'artist': 'YHWH Nailgun', 'title': 'Sickle Walk'}, {'artist': 'Little Simz', 'title': 'Flood'}, {'artist': 'Everything Is Recorded', 'title': 'Never Felt Better'}, {'artist': 'The Jesus and Mary Chain', 'title': 'Just Like Honey'}, {'artist': 'Ezra Furman', 'title': 'Grand Mal'}, {'artist': 'The Limiñanas', 'title': 'Ou Va Le Chance'}, {'artist': 'Pigs Pigs Pigs Pigs Pigs Pigs Pigs', 'title': 'Stitches'}, {'artist': 'Tiberius b', 'title': 'SUGAR RUSH'}, {'artist': 'The Clientele', 'title': "(I Can't Seem to) Make You Mine"}, {'artist': 'JAY-Z', 'title': 'Izzo (H.O.V.A.)'}, {'artist': 'The Streets', 'title': 'Weak Become Heroes'}, {'artist': 'KNEECAP', 'title': 'H.O.O.D 2025'}, {'artist': 'Radiohead', 'title': 'Exit Music (For A Film)'}, {'artist': 'X‐Press 2', 'title': 'Lazy'}, {'artist': 'Björk', 'title': "It's Oh So Quiet"}, {'artist': 'Deep Purple', 'title': 'Hush'}, {'artist': 'Sampa the Great', 'title': "Time's Up"}, {'artist': 'Doechii', 'title': 'Nosebleeds'}, {'artist': 'M.I.A.', 'title': 'Boyz'}, {'artist': 'Waxahatchee', 'title': 'Mud'}, {'artist': 'Saya Gray', 'title': "..THUS IS WHY ( I DON'T SPRING 4 LOVE )"}, {'artist': 'Loraine James', 'title': 'I DM U'}, {'artist': 'Sinéad O’Connor', 'title': 'Mandinka'}]

# %%
import pandas as pd

df = pd.DataFrame(tracks)

df
# Out:
#                                 artist  \
# 0                           Wolf Alice
# 1                       Fontaines D.C.
# 2                               Prince
# 3                           Lou Hayter
# 4                                Yello
# 5                       Snapped Ankles
# 6                           Jacob Alon
# 7               Sly & the Family Stone
# 8                             Iggy Pop
# 9               Sly & the Family Stone
# 10                     Jungle Brothers
# 11                       Janet Jackson
# 12                          St Germain
# 13                  Emma‐Jean Thackray
# 14                          Obongjayar
# 15                           Femi Kuti
# 16                        YHWH Nailgun
# 17                         Little Simz
# 18              Everything Is Recorded
# 19            The Jesus and Mary Chain
# 20                         Ezra Furman
# 21                       The Limiñanas
# 22  Pigs Pigs Pigs Pigs Pigs Pigs Pigs
# 23                          Tiberius b
# 24                       The Clientele
# 25                               JAY-Z
# 26                         The Streets
# 27                             KNEECAP
# 28                           Radiohead
# 29                           X‐Press 2
# 30                               Björk
# 31                         Deep Purple
# 32                     Sampa the Great
# 33                             Doechii
# 34                              M.I.A.
# 35                         Waxahatchee
# 36                           Saya Gray
# 37                       Loraine James
# 38                     Sinéad O’Connor
#
#                                        title
# 0                    Don't Delete The Kisses
# 1                   It's Amazing To Be Young
# 2                                Controversy
# 3   Frequency (Joe Goddard & Al Doyle Remix)
# 4                                    Bostich
# 5                                      Raoul
# 6                             Liquid Gold 25
# 7                                     Stand!
# 8                              Family Affair
# 9                         Sing A Simple Song
# 10                Because I Got It Like That
# 11                             Rhythm Nation
# 12                                Rose Rouge
# 13                                 Wanna Die
# 14                          Not In Surrender
# 15                            After 24 Years
# 16                               Sickle Walk
# 35  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 36  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 37  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 38  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 39  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 40  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 41  Lauren Laverne  Jump start your mid-morning with the biggest a...
# 42  Lauren Laverne  Jump start your mid-morning with the biggest a...
#
#                     artist                                     title  \
# 0   Sly & the Family Stone  Thank You (Falettinme Be Mice Elf Again)
# 1          Ezra Collective                             Body Language
# 2             David Holmes                          Necessary Genius
# 3               Obongjayar                          Not In Surrender
# 4                Goldfrapp                               Lovely Head
# 5                       雪見                                Sad Makeup
# 6           Perfume Genius                             It's a Mirror
# 7                FKA twigs                                Striptease
# 8                  Dr. Dre                          The Next Episode
# 9                Mura Masa                                      rise
# 10   The Chemical Brothers                               Do It Again
# 11                   James                                 Come Home
# 12                 Odyssey                    Going Back To My Roots
# 13               Daft Punk          Harder, Better, Faster, Stronger
# 14            BC Camplight                The Last Rotation of Earth
# 15                Bon Iver               Everything Is Peaceful Love
# 16                 JayWood                                 BIG TINGS
# 17         Dilated Peoples                                Back Again
# 18                Jamie xx                                      F.U.
# 19               Huarinami                               Girl I Know
# 20               Horsegirl                               Switch Over
# 21                    Beck                                Tropicalia
# 22      Emma‐Jean Thackray                                 Wanna Die
# 23       Thee Sacred Souls                 Waiting on the Right Time
# 24             Waxahatchee                                       Mud
# 25             St. Panther                                   Highway
# 26               Radiohead                                  Reckoner
# 27                   bdrmm                       Lake Disappointment
# 28                Gabriels         Love And Hate In A Different Time
# 29             Ezra Furman                                 Grand Mal
# 30                Elastica                                 Waking Up
# 31                    Pulp                                Disco 2000
# 32                Menswear                                Daydreamer
# 33           Songhoy Blues              Bon Bon (Mike Lindsay Remix)
# 34           Saâda Bonaire              You Could Be More As You Are
# 35      Japanese Breakfast                              Mega Circuit
# 36         TV on the Radio                              Wolf Like Me
# 37                 KNEECAP                              H.O.O.D 2025
# 38               The Clash                       The Guns Of Brixton
# 39                  Σtella                                Omorfo Mou
# 40           Maribou State                               II Remember
# 41         Laurie Anderson                                   Let X=X
# 42                Hot Chip                              Need You Now
#
#    featured_artists
# 0              None
# 1    [Sasha Keable]
# 2    [Raven Violet]
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8      [Snoop Dogg]
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14             None
# 15             None
# 16     [tUnE-yArDs]
# 17             None
# 18    [Erykah Badu]
# 19             None
# 20             None
# 21             None
# 22             None
# 23             None
# 24             None
# 25             None
# 26             None
# 27             None
# 28             None
# 29             None
# 30             None
# 31             None
# 32             None
# 33             None
# 34             None
# 35             None
# 36             None
# 37             None
# 38             None
# 39             None
# 40             None
# 41             None
# 42             None

# %%
import time
import re
from datetime import datetime

# %%
def scrape_bbc6_episode(url):
    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    
    # Initialize the driver
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url)
    
    try:
        # Wait for the page to load
        WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CLASS_NAME, "segments-list__item"))
        )
        
        # Click "Show more" button if it exists to reveal all tracks
        try:
            show_more = driver.find_element(By.CLASS_NAME, "ml__label--more")
            driver.execute_script("arguments[0].click();", show_more)
            time.sleep(2)  # Wait for animation to complete
        except:
            pass  # No "Show more" button or already expanded
        
        # Get DJ name
        dj_name = driver.find_element(By.CSS_SELECTOR, "a.context__item").text
        
        # # Get episode title
        # episode_title = driver.find_element(By.CSS_SELECTOR, "h1.no-margin").text
        
        # Extract episode date
        episode_date = None
        try:
            # Look for the span with title containing the date
            meta_span = driver.find_element(By.CSS_SELECTOR, "p.episode-panel__meta span[title]")
            date_str = meta_span.get_attribute("title")
            
            # Extract date using regex
            date_match = re.search(r'(\w{3} \d{1,2} \w+ \d{4})', date_str)
            if date_match:
                date_str = date_match.group(1)
                # Parse the date
                episode_date = datetime.strptime(date_str, "%a %d %B %Y").strftime("%Y-%m-%d")
            else:
                # Try alternative date format in the broadcast event
                broadcast_date = driver.find_element(By.CSS_SELECTOR, ".broadcast-event__time[title]")
                if broadcast_date:
                    date_str = broadcast_date.get_attribute("title")
                    episode_date = datetime.strptime(date_str, "%d %b %Y").strftime("%Y-%m-%d")
        except Exception as e:
            print(f"Error extracting date: {e}")
            # Fallback to URL to extract episode ID and date if possible
            try:
                episode_id = url.split('/')[-1]
                # If episode ID contains date format (common in BBC URLs)
                # You might need to adjust this regex based on actual URL patterns
                date_match = re.search(r'(\d{8})', episode_id)
                if date_match:
                    date_str = date_match.group(1)
                    episode_date = f"{date_str[:4]}-{date_str[4:6]}-{date_str[6:8]}"
            except:
                episode_date = "Unknown Date"
        
        # Extract all music segments
        music_segments = driver.find_elements(By.CSS_SELECTOR, "li.segments-list__item--music")
        
        tracks = []
        for index, segment in enumerate(music_segments, 1):
            try:
                # Extract artist
                artist_elem = segment.find_element(By.CLASS_NAME, "artist")
                artist = artist_elem.text if artist_elem else "Unknown Artist"
                
                # Extract track title
                title_container = segment.find_element(By.CSS_SELECTOR, "p.no-margin")
                title_span = title_container.find_element(By.TAG_NAME, "span")
                title = title_span.text if title_span else "Unknown Title"
                
                # Add to our list
                tracks.append({
                    'dj': dj_name,
                    'episode_date': episode_date,
                    'track_order': index,
                    'artist': artist,
                    'title': title,
                })
            except Exception as e:
                print(f"Error extracting track {index}: {e}")
                continue
        
        return pd.DataFrame(tracks)
        
    finally:
        driver.quit()

# %%
df = scrape_bbc6_episode(episode_url)
df
# Out:
#                 dj episode_date  track_order                  artist  \
# 0   Lauren Laverne   2025-03-26            1  Sly & the Family Stone
# 1   Lauren Laverne   2025-03-26            2         Ezra Collective
# 2   Lauren Laverne   2025-03-26            3            David Holmes
# 3   Lauren Laverne   2025-03-26            4              Obongjayar
# 4   Lauren Laverne   2025-03-26            5               Goldfrapp
# 5   Lauren Laverne   2025-03-26            6                      雪見
# 6   Lauren Laverne   2025-03-26            7          Perfume Genius
# 7   Lauren Laverne   2025-03-26            8               FKA twigs
